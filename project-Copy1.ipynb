# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C://Users//SUNITHA//OneDrive//Documents//city_day.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df=pd.read_csv("C://Users//SUNITHA//OneDrive//Documents//city_day.csv")
#
# NameError: name 'pd' is not defined

# %%
df

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.tail()
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
#
# NameError: name 'df' is not defined

# %%
print(df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(df.isnull().sum())
#
# NameError: name 'df' is not defined

# %%
(df.isnull().sum()/df.shape[0]*100).sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 (df.isnull().sum()/df.shape[0]*100).sort_values(ascending=False)
#
# NameError: name 'df' is not defined

# %%
df['Date']=df['Date'].apply(pd.to_datetime)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df['Date']=df['Date'].apply(pd.to_datetime)
#
# NameError: name 'df' is not defined

# %%
  df.set_index('Date',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.set_index('Date',inplace=True)
#
# NameError: name 'df' is not defined

# %%
  df.iloc[:, 0:13]=df.fillna(df.mean(numeric_only=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.iloc[:, 0:13]=df.fillna(df.mean(numeric_only=True))
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
#
# NameError: name 'df' is not defined

# %%
 def get_PM10_subindex(x): 
    if x <= 50: 
        return x 
    elif x > 50 and x <= 100: 
        return x 
    elif x > 100 and x <= 250: 
        return 100 + (x - 100) * 100 / 150 
    elif x > 250 and x <= 350: 

        return 200 + (x - 250) 

    elif x > 350 and x <= 430: 

        return 300 + (x - 350) * 100 / 80 

    elif x > 430: 

        return 400 + (x - 430) * 100 / 80 

    else: 

        return 0

# %%
df['PM10_SubIndex'] = df['PM10'].astype(int).apply(lambda x: get_PM10_subindex(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df['PM10_SubIndex'] = df['PM10'].astype(int).apply(lambda x: get_PM10_subindex(x))
#
# NameError: name 'df' is not defined

# %%
print(df['PM10_SubIndex'])
# Out:
# Date
# 2015-01-01    112.0
# 2015-01-02    112.0
# 2015-01-03    112.0
# 2015-01-04    112.0
# 2015-01-05    112.0
#               ...
# 2020-06-27     50.0
# 2020-06-28     74.0
# 2020-06-29     65.0
# 2020-06-30     49.0
# 2020-07-01     66.0
# Name: PM10_SubIndex, Length: 29531, dtype: float64

# %%
print(df)
# Out:
#                      City      PM2.5        PM10     NO    NO2    NOx  \
# Date
# 2015-01-01      Ahmedabad  67.450578  118.127103   0.92  18.22  17.15
# 2015-01-02      Ahmedabad  67.450578  118.127103   0.97  15.69  16.46
# 2015-01-03      Ahmedabad  67.450578  118.127103  17.40  19.30  29.70
# 2015-01-04      Ahmedabad  67.450578  118.127103   1.70  18.48  17.97
# 2015-01-05      Ahmedabad  67.450578  118.127103  22.10  21.42  37.76
# ...                   ...        ...         ...    ...    ...    ...
# 2020-06-27  Visakhapatnam  15.020000   50.940000   7.68  25.06  19.54
# 2020-06-28  Visakhapatnam  24.380000   74.090000   3.42  26.06  16.53
# 2020-06-29  Visakhapatnam  22.910000   65.730000   3.45  29.53  18.33
# 2020-06-30  Visakhapatnam  16.640000   49.970000   4.05  29.26  18.80
# 2020-07-01  Visakhapatnam  15.000000   66.000000   0.40  26.85  14.05
#
#                   NH3     CO    SO2      O3  Benzene    Toluene    Xylene  \
# Date
# ...

# %%
def get_PM25_subindex(x): 

    if x <= 30: 

        return x * 50 / 30 

    elif x > 30 and x <= 60: 

        return 50 + (x - 30) * 50 / 30 

    elif x > 60 and x <= 90: 

        return 100 + (x - 60) * 100 / 30 

    elif x > 90 and x <= 120: 

        return 200 + (x - 90) * 100 / 30 

    elif x > 120 and x <= 250: 

        return 300 + (x - 120) * 100 / 130 

    elif x > 250: 

        return 400 + (x - 250) * 100 / 130 

    else: 

        return 0

# %%
df['PM2.5_SubIndex'] = df['PM2.5'].astype(int).apply(lambda x: get_PM25_subindex(x))

# %%
def get_SO2_subindex(x): 

    if x <= 40: 

        return x * 50 / 40 

    elif x > 40 and x <= 80: 

        return 50 + (x - 40) * 50 / 40 

    elif x > 80 and x <= 380: 

        return 100 + (x - 80) * 100 / 300 

    elif x > 380 and x <= 800: 

        return 200 + (x - 380) * 100 / 420 

    elif x > 800 and x <= 1600: 

        return 300 + (x - 800) * 100 / 800 

    elif x > 1600: 

        return 400 + (x - 1600) * 100 / 800 

    else: 

        return 0

# %%
df['SO2_SubIndex'] = df['SO2'].astype(int).apply(lambda x: get_SO2_subindex(x))

# %%
def get_Nox_subindex(x): 

    if x <= 40: 

        return x * 50 / 40 

    elif x > 40 and x <= 80: 

        return 50 + (x - 40) * 50 / 40 

    elif x > 80 and x <= 180: 

        return 100 + (x - 80) * 100 / 100 

    elif x > 180 and x <= 280: 

        return 200 + (x - 180) * 100 / 100 

    elif x > 280 and x <= 400: 

        return 300 + (x - 280) * 100 / 120 

    elif x > 400: 

        return 400 + (x - 400) * 100 / 120 

    else: 

        return 0 

 

df['Nox_SubIndex'] = df['NO'].astype(int).apply(lambda x: get_Nox_subindex(x))

# %%
# NH3 Sub-Index calculation 

def get_NH3_subindex(x): 

    if x <= 200: 

        return x * 50 / 200 

    elif x > 200 and x <= 400: 

        return 50 + (x - 200) * 50 / 200 

    elif x > 400 and x <= 800: 

        return 100 + (x - 400) * 100 / 400 

    elif x > 800 and x <= 1200: 

        return 200 + (x - 800) * 100 / 400 

    elif x > 1200 and x <= 1800: 

        return 300 + (x - 1200) * 100 / 600 

    elif x > 1800: 

        return 400 + (x - 1800) * 100 / 600 

    else: 

        return 0

# %%
df['NH3_SubIndex'] = df['NH3'].astype(int).apply(lambda x: get_NH3_subindex(x))

# %%
def get_CO_subindex(x): 

    if x <= 1: 

        return x * 50 / 1 

    elif x > 1 and x <= 2: 

        return 50 + (x - 1) * 50 / 1 

    elif x > 2 and x <= 10: 

        return 100 + (x - 2) * 100 / 8 

    elif x > 10 and x <= 17: 

        return 200 + (x - 10) * 100 / 7 

    elif x > 17 and x <= 34: 

        return 300 + (x - 17) * 100 / 17 

    elif x > 34: 

        return 400 + (x - 34) * 100 / 17 

    else: 

        return 0 

 

df['CO_SubIndex'] = df['CO'].astype(int).apply(lambda x: get_CO_subindex(x))

# %%
def get_O3_subindex(x): 

    if x <= 50: 

        return x * 50 / 50 

    elif x > 50 and x <= 100: 

        return 50 + (x - 50) * 50 / 50 

    elif x > 100 and x <= 168: 

        return 100 + (x - 100) * 100 / 68 

    elif x > 168 and x <= 208: 

        return 200 + (x - 168) * 100 / 40 

    elif x > 208 and x <= 748: 

        return 300 + (x - 208) * 100 / 539 

    elif x > 748: 

        return 400 + (x - 400) * 100 / 539 

    else: 

        return 0 

 

df['O3_SubIndex'] = df['O3'].astype(int).apply(lambda x: get_O3_subindex(x))

# %%
df['AQI'] = df['AQI'].fillna(df[['PM2.5_SubIndex','PM10_SubIndex','SO2_SubIndex','Nox_SubIndex','NH3_SubIndex','CO_SubIndex','O3_SubIndex']].max(axis = 1))

# %%
df.head()
# Out:
#                  City      PM2.5        PM10     NO    NO2    NOx        NH3  \
# Date
# 2015-01-01  Ahmedabad  67.450578  118.127103   0.92  18.22  17.15  23.483476
# 2015-01-02  Ahmedabad  67.450578  118.127103   0.97  15.69  16.46  23.483476
# 2015-01-03  Ahmedabad  67.450578  118.127103  17.40  19.30  29.70  23.483476
# 2015-01-04  Ahmedabad  67.450578  118.127103   1.70  18.48  17.97  23.483476
# 2015-01-05  Ahmedabad  67.450578  118.127103  22.10  21.42  37.76  23.483476
#
#                CO    SO2      O3  ...  Xylene         AQI  AQI_Bucket  \
# Date                              ...
# 2015-01-01   0.92  27.64  133.36  ...    0.00  148.529412         NaN
# 2015-01-02   0.97  24.55   34.06  ...    3.77  123.333333         NaN
# 2015-01-03  17.40  29.07   30.70  ...    2.25  300.000000         NaN
# 2015-01-04   1.70  18.59   36.08  ...    1.00  123.333333         NaN
# 2015-01-05  22.10  39.33   39.31  ...    2.78  329.411765         NaN
#
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: ylabel='Date'>

# %%
def get_AQI_bucket(x): 

    if x <= 50: 

        return 'Good' 

    elif x > 50 and x <= 100: 

        return 'Satisfactory' 

    elif x > 100 and x <= 200: 

        return 'Moderate' 

    elif x > 200 and x <= 300: 

        return 'Poor' 

    elif x > 300 and x <= 400: 

        return 'Very Poor' 

    elif x > 400: 

        return 'Severe'

    else: 

        return '0'

# %%
df['AQI_Bucket'] = df['AQI_Bucket'].fillna(df['AQI'].apply(lambda x: get_AQI_bucket(x)))

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: ylabel='Date'>

# %%
pollutants = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2','O3', 'Benzene', 'Toluene', 'Xylene']

# %%
df_city_day = df[pollutants]

# %%
print('Distribution of different pollutants in last 5 years') 

df_city_day.plot(kind='line',figsize=(18,18),cmap='coolwarm',subplots=True,fontsize=10); 

df[['City','AQI']].groupby('City').mean().sort_values('AQI').plot(kind='bar',cmap='Blues_r',figsize=(8,8)) 

plt.title('Average AQI in last 5 years'); 

final_df= df[['AQI', 'AQI_Bucket']].copy() 

final_df
# Out:
# Distribution of different pollutants in last 5 years
#                    AQI    AQI_Bucket
# Date
# 2015-01-01  148.529412      Moderate
# 2015-01-02  123.333333      Moderate
# 2015-01-03  300.000000          Poor
# 2015-01-04  123.333333      Moderate
# 2015-01-05  329.411765     Very Poor
# ...                ...           ...
# 2020-06-27   41.000000          Good
# 2020-06-28   70.000000  Satisfactory
# 2020-06-29   68.000000  Satisfactory
# 2020-06-30   54.000000  Satisfactory
# 2020-07-01   50.000000          Good
#
# [29531 rows x 2 columns]

# %%
a=df.drop('City',axis=1)

# %%
df1 = pd.DataFrame(a)

# %%
df1.head()
# Out:
#                 PM2.5        PM10     NO    NO2    NOx        NH3     CO  \
# Date
# 2015-01-01  67.450578  118.127103   0.92  18.22  17.15  23.483476   0.92
# 2015-01-02  67.450578  118.127103   0.97  15.69  16.46  23.483476   0.97
# 2015-01-03  67.450578  118.127103  17.40  19.30  29.70  23.483476  17.40
# 2015-01-04  67.450578  118.127103   1.70  18.48  17.97  23.483476   1.70
# 2015-01-05  67.450578  118.127103  22.10  21.42  37.76  23.483476  22.10
#
#               SO2      O3  Benzene  ...  Xylene         AQI  AQI_Bucket  \
# Date                                ...
# 2015-01-01  27.64  133.36     0.00  ...    0.00  148.529412    Moderate
# 2015-01-02  24.55   34.06     3.68  ...    3.77  123.333333    Moderate
# 2015-01-03  29.07   30.70     6.80  ...    2.25  300.000000        Poor
# 2015-01-04  18.59   36.08     4.43  ...    1.00  123.333333    Moderate
# 2015-01-05  39.33   39.31     7.01  ...    2.78  329.411765   Very Poor
#
# ...

# %%
final_df= df[['AQI','PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2','O3', 'Benzene', 'Toluene', 'Xylene']].copy()

# %%
df2 = pd.DataFrame(final_df)
df2.head()
# Out:
#                    AQI      PM2.5        PM10     NO    NO2    NOx        NH3  \
# Date
# 2015-01-01  148.529412  67.450578  118.127103   0.92  18.22  17.15  23.483476
# 2015-01-02  123.333333  67.450578  118.127103   0.97  15.69  16.46  23.483476
# 2015-01-03  300.000000  67.450578  118.127103  17.40  19.30  29.70  23.483476
# 2015-01-04  123.333333  67.450578  118.127103   1.70  18.48  17.97  23.483476
# 2015-01-05  329.411765  67.450578  118.127103  22.10  21.42  37.76  23.483476
#
#                CO    SO2      O3  Benzene  Toluene  Xylene
# Date
# 2015-01-01   0.92  27.64  133.36     0.00     0.02    0.00
# 2015-01-02   0.97  24.55   34.06     3.68     5.50    3.77
# 2015-01-03  17.40  29.07   30.70     6.80    16.40    2.25
# 2015-01-04   1.70  18.59   36.08     4.43    10.14    1.00
# 2015-01-05  22.10  39.33   39.31     7.01    18.89    2.78

# %%
X= df2[['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2','O3', 'Benzene', 'Toluene', 'Xylene']]
y = df2[['AQI']]

# %%
#y = final_df[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']]

# %%
from sklearn.model_selection import  train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=42)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (8859, 12) (20672, 12) (8859, 1) (20672, 1)

# %%
from sklearn import preprocessing
from sklearn import utils

lab_enc = preprocessing.LabelEncoder()
encoded = lab_enc.fit_transform(y_train.values.ravel())


print(utils.multiclass.type_of_target(y_train.values.ravel()))


print(utils.multiclass.type_of_target(y_train.values.ravel().astype('int')))


print(utils.multiclass.type_of_target(encoded))
# Out:
# continuous
# multiclass
# multiclass

# %%
from sklearn.ensemble import RandomForestRegressor

model1 = RandomForestRegressor()

from sklearn.linear_model import LinearRegression

model2 = LinearRegression()  

import sklearn.metrics as sm


model1.fit(X_train, encoded)

model2.fit(X_train, encoded)



## Predict Test set results
y_pred1 = model1.predict(X_test)
y_pred2 = model2.predict(X_test)



#df1 = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred1})  

#print(df1)



y_pred1=np.array(y_pred1).reshape(-1,1)


y_pred2=np.array(y_pred2).reshape(-1,1)



accuracy=sm.r2_score(y_test,y_pred1)
      
print("Accuracy of RandomForestRegressor is  {:.2f} % ".format(accuracy*100))

accuracy=sm.r2_score(y_test,y_pred2)
      
print("Accuracy of LinearRegression is {:.2f} % ".format(accuracy*100))
# Out:
# Accuracy of RandomForestRegressor is  81.63 %
# Accuracy of LinearRegression is 79.58 %

# %%
from sklearn.metrics import mean_squared_error
import math
# root mean square calculated by sklearn package
mse1 = math.sqrt(mean_squared_error(y_test, y_pred1))
print('Root mean square error', mse1)

# where as the another way to find RMSE
# is by adding squared attribute as false in mean_squared_error
mse2 = mean_squared_error(y_test, y_pred1, squared=False)
print('Root mean square error', mse2)
from sklearn.metrics import r2_score
 
# r2 error calculated by sklearn is similar
# to ours mathematically calculated r2 error
# calculate r2 error using sklearn
r2_score(y_test, y_pred1)
# Out:
# Root mean square error 56.17980084291403
# Root mean square error 56.17980084291403
# 0.8163051963439275

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test,y_pred1)
# Out:
# 3156.1700227494835

# %%
print(y_pred1)
# Out:
# [[131.  ]
#  [131.  ]
#  [136.04]
#  ...
#  [122.13]
#  [416.49]
#  [128.15]]

# %%
y_pred1
# Out:
# array([[131.  ],
#        [131.  ],
#        [136.04],
#        ...,
#        [122.13],
#        [416.49],
#        [128.15]])

# %%
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
print(RandomForestClassifier())
print(RandomForestRegressor())
# Out:
# RandomForestClassifier()
# RandomForestRegressor()

# %%
from sklearn.svm import SVR
model3=SVR()
model3.fit(X_train, encoded)
y_pred3 = model3.predict(X_test)
y_pred3=np.array(y_pred3).reshape(-1,1)
accuracy=sm.r2_score(y_test,y_pred3)
      
print("Accuracy of SVR is  {:.2f} % ".format(accuracy*100))
# Out:
# Accuracy of SVR is  56.99 %

# %%
from sklearn.ensemble import AdaBoostRegressor
model4=AdaBoostRegressor()
model4.fit(X_train, encoded)
y_pred4 = model4.predict(X_test)
y_pred4=np.array(y_pred4).reshape(-1,1)
accuracy=sm.r2_score(y_test,y_pred4)
print("Accuracy of AdaBoostRegressor is  {:.2f} % ".format(accuracy*100))
# Out:
# Accuracy of AdaBoostRegressor is  49.97 %

# %%
from sklearn.naive_bayes import GaussianNB  
classifier = GaussianNB() 
classifier.fit(X_train, encoded)
y_pred5 = classifier.predict(X_test)
y_pred5=np.array(y_pred5).reshape(-1,1)
accuracy=sm.r2_score(y_test,y_pred5)
print("Accuracy of GaussianNB is  {:.2f} % ".format(accuracy*100))
# Out:
# Accuracy of GaussianNB is  -21.66 %

# %%
from sklearn.tree import DecisionTreeRegressor
classifier= DecisionTreeRegressor()
classifier.fit(X_train, encoded)
y_pred5 = classifier.predict(X_test)
y_pred5=np.array(y_pred5).reshape(-1,1)
accuracy=sm.r2_score(y_test,y_pred5)
print("Accuracy of DecisionTreeClassifier is  {:.2f} % ".format(accuracy*100))
# Out:
# Accuracy of DecisionTreeClassifier is  74.88 %

# %%
#from  import joblib 
import joblib
# Save the model as a pickle in a file 
joblib.dump(model1, 'final_pickle_model.pkl') 
  
# Load the model from the file 
final_model= joblib.load('final_pickle_model.pkl')

pred=final_model.predict(X_test)

accuracy=sm.r2_score(y_test,pred)
      
print("Accurcay of Final Model is {:.2f} % ".format(accuracy*100))
# Out:
# Accurcay of Final Model is 81.63 %

# %%
import pickle

import pandas as pd

import os, uuid, sys



import numpy as np

from flask import Flask, request, render_template

import joblib






# Load the model from the file 
model = joblib.load('final_pickle_model.pkl')  
  
# Create Flask object to run

app = Flask(__name__)

@app.route('/')

def home():
    return render_template("index1.html")
    #AQI = request.args["AQI"]
   # AQI = int(AQI)



@app.route('/predict',methods=['POST'])
def predict():
    int_features = [str(x) for x in request.form.values()]
   # print(int_features)
    a=int_features
    
    PM2_5 = float(a[0])
    PM10=float(a[1])
    NO = float(a[2])
    NO2 =float(a[3])
    NOx = float(a[4])
    NH3=float(a[6])                       
    CO=float(a[7])
    SO2=float(a[5])
    O3=float(a[8])
    Benzene=float(a[9])
    Toluene=float(a[10])
    Xylene=float(a[11])
    

    data= {'PM2.5':[PM2_5],'PM10':[PM10],'NO':[NO],'NO2':[NO2],'NOx':[NOx],'NH3':[NH3],'CO':[CO],'SO2':[SO2],'O3':[O3],'Benzene':[Benzene],'Toluene':[Toluene],'Xylene':[Xylene]} 
    df = pd.DataFrame(data)
      
# Print the output. 
    print(df )
    prediction=model.predict(df)
    prediction=int(prediction)
    

    

    if((prediction>=0) and (prediction<=50)):
        return render_template('index1.html',prediction_text='Air Quality Index  is {}'.format(prediction),prediction_text1='Air Quality is Good')
        
        
    
    if((prediction>=51) and (prediction<=100)):
        return render_template('index1.html',prediction_text='Air Quality Index   is {}'.format(prediction),prediction_text1='Air Quality is Moderate')
       
     
        
    if((prediction>=101) and (prediction<=150)):
        return render_template('index1.html',prediction_text='Air Quality Index  is {}'.format(prediction),prediction_text1='Air Quality is Unhealthy')
       
       
        
    if((prediction>=151) and (prediction<=200)):
        return render_template('index1.html',prediction_text='Air Quality Index   is {}'.format(prediction),prediction_text1='Air Quality is Unhealthy for Strong People')
        
        
    if(prediction>201):
        return render_template('index1.html',prediction_text='Air Quality Index  is {}'.format(prediction),prediction_text1='Air Quality is Hazaradous')
   

   
    # pass AQI to the model, predict
    
    # send the prediction to client
    #return f"predict page AQI - {AQI}"

    



   

if __name__ == "__main__":
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [21/Apr/2023 10:01:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 10:01:07] "GET /favicon.ico HTTP/1.1" 404 -
